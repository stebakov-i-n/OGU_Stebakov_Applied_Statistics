# %% [markdown]
# ### Параметрические критерии
#
# ![image.png](attachment:image.png)

# %%
# Импортирование нужной статистики из модуля scipy.stats
from scipy.stats import ?

# Исходные данные

# Вычисление статистики
some_stat = 

# Расчет числа степеней свободы (при необходимости)
df = ?

# Критическое значение F-распределения
some_stat_crit = ? # Необходимо применить функцию ppf, а также учесть вид распределений гипотез

print(f"Критическое значение some stat: {some_stat_crit}")

# Вычисление p-value
p_value = ? # Необходимо применить функцию cdf, а также учесть вид распределений и гипотез

print(f"p-value: {p_value}")

# Выводы о гипотезах

# %% [markdown]
# ### Примерные контрольные вопросы
#
# Что такое нулевая и альтернативная гипотезы? Приведите примеры для задания на сравнение средних и дисперсий.
#
# Какие параметрические критерии используются для проверки гипотез о равенстве средних? Укажите условия их применения.
#
# Какие критерии применяются для проверки гипотез о равенстве дисперсий? В чем их различия?
#
# Что такое уровень значимости критерия? Как он влияет на принятие или отклонение нулевой гипотезы?
