# %% [markdown]
# ### Задание 1.
#
# По двум выборкам объема n_x=14, n_y=16, из нормальных ГС рассчитаны исправленные выборочные дисперсии $S_x^2\approx12.52$, $S_y^2\approx10.35$; Задав уровень значимости 0.1 проверить гипотезы H0: DX = DY при H1: DX > DY.
#
# Используя критерий Фишера рассчитать критическое значение и p-value.
#
# На основе полученных значений сделать вывод о принятии нулевой гипотезы (добавить текстовый вывод).

# %%
from scipy.stats import f

# Данные
Sx2 = 12.52  # Исправленная дисперсия первой выборки
Sy2 = 10.35  # Исправленная дисперсия второй выборки
n_x = 14     # Объем первой выборки
n_y = 16     # Объем второй выборки
alpha = 0.01 # Уровень значимости

# Вычисление F-статистики
F = Sx2 / Sy2
print(f"F-статистика: {F}")

# Число степеней свободы
df1 = n_x - 1
df2 = n_y - 1

# Критическое значение F-распределения
F_crit = ?

print(f"Критическое значение F: {F_crit}")

# Вычисление p-value
p_value = ?

print(f"p-value: {p_value}")

# Выводы о гипотезах

# %% [markdown]
# ### Задание 2.
#
# Партия изделий принимается, если дисперсия контролируемого параметра не превышает 0.2. Исправленная выборочная дисперсия, найденная по выборке $n=120$, оказалась равной $S_x^2=0.3$. Можно ли принять партию при уровне значимости $\alpha=0.01$?
#
# Используя критерий Пирсона рассчитать критическое значение и p-value.
#
# $\chi^2 = \frac{(n - 1) S_X^2}{\sigma_0^2}.$
#
#
# На основе полученных значений сделать вывод о принятии нулевой гипотезы (добавить текстовый вывод).

# %%
from scipy.stats import chi2

# Данные
n = 120  # Объем выборки
Sx2 = 0.3  # Исправленная выборочная дисперсия
sigma0_2 = 0.2  # Максимально допустимая дисперсия
alpha = 0.01  # Уровень значимости

# Вычисление χ²-статистики
chi2_stat = ?
print(f"χ²-статистика: {chi2_stat}")

# Число степеней свободы
df = n - 1

# Критическое значение χ²-распределения
chi2_crit = ?
print(f"Критическое значение χ²: {chi2_crit}")

# Вычисление p-value
p_value = ?
print(f"p-value: {p_value}")

# Выводы о гипотезах

# %% [markdown]
# ### Задание 3.
#
# По двум независимым выборкам объемов  $n_1=40, n_2=50$ извлеченных из нормальных ГС, найдены выборочные средние $\bar{x} =130$, $\bar{y} =140$. Генеральные дисперсии известны:  $D(X)=80, D(Y)=100$. На уровне значимости $\alpha=0.01$ проверить гипотезу о равенстве средних  $MX=MY$, при альтернативной  $MX≠XY$.
#
# Используя z критерий рассчитать критическое значение и p-value.
#
# $z = \frac{\bar{X} - \bar{Y}}{\sqrt{\frac{\sigma_X^2}{n_X} + \frac{\sigma_Y^2}{n_Y}}}$
#
# На основе полученных значений сделать вывод о принятии нулевой гипотезы (добавить текстовый вывод).

# %%
import numpy as np
from scipy.stats import norm

# Данные
n_X = 40  # Объем первой выборки
n_Y = 50  # Объем второй выборки
X_bar = 130  # Выборочное среднее первой выборки
Y_bar = 140  # Выборочное среднее второй выборки
sigma_X2 = 80  # Генеральная дисперсия первой совокупности
sigma_Y2 = 100  # Генеральная дисперсия второй совокупности
alpha = 0.01  # Уровень значимости

# Вычисление z-статистики
z = ?
print(f"z-статистика: {z}")

# Критическое значение для двусторонней гипотезы
z_crit = ?
print(f"Критическое значение z: {z_crit}")

# Вычисление p-value
p_value = ?
print(f"p-value: {p_value}")

# Выводы о гипотезах

# %% [markdown]
# ### Задание 4.
#
# По двум независимым выборкам объемов  $n_1=10, n_2=8$ извлеченных из нормальных ГС, найдены выборочные средние  $\bar{x} =142.3$, $\bar{y} =145.3$. и исправленные выборочные дисперсии:  $S_x^2=2.7, S_y^2=3.2$. На уровне значимости $\alpha=0.01$ проверить гипотезу о равенстве средних  $MX=MY$, при альтернативной  $MX≠XY$.
#
# Используя критерий Стьюдента рассчитать критическое значение и p-value.
#
# $S_p^2 = \frac{(n_X - 1) S_X^2 + (n_Y - 1) S_Y^2}{n_X + n_Y - 2},$
#
# $t = \frac{\bar{X} - \bar{Y}}{S_p \sqrt{\frac{1}{n_X} + \frac{1}{n_Y}}}.$
#
# На основе полученных значений сделать вывод о принятии нулевой гипотезы (добавить текстовый вывод).

# %%
import numpy as np
from scipy.stats import t

# Данные
n_X = 10  # Объем первой выборки
n_Y = 8  # Объем второй выборки
X_bar = 142.3  # Выборочное среднее первой выборки
Y_bar = 145.3  # Выборочное среднее второй выборки
S_X2 = 2.7  # Исправленная выборочная дисперсия первой выборки
S_Y2 = 3.2  # Исправленная выборочная дисперсия второй выборки
alpha = 0.01  # Уровень значимости

# Вычисление объединенной дисперсии
S_p2 = ?

# Вычисление t-статистики
t_stat = ?
print(f"t-статистика: {t_stat}")

# Число степеней свободы
df = n_X + n_Y - 2

# Критическое значение для двусторонней гипотезы
t_crit = ?
print(f"Критическое значение t: {t_crit}")

# Вычисление p-value
p_value = ?
print(f"p-value: {p_value}")

# Выводы о гипотезах

# %% [markdown]
# ### Задание 5.
#
# Проектный контролируемый размер изделий, изготавливаемых станком-автоматом, $\mu=35$ мм. Измерения 20 случайно отобранных изделий приведены в массиве data. При уровне значимости $\alpha=0.05$ ответить на вопрос: обеспечивает ли станок проектный размер изделий?
#
# Используя критерий Стьюдента рассчитать критическое значение и p-value.
#
# $t = \frac{\bar{X} - \mu_0}{S / \sqrt{n}}.$
#
# На основе полученных значений сделать вывод о принятии нулевой гипотезы (добавить текстовый вывод).

# %%
import numpy as np
from scipy.stats import t

# Данные (пример)
data = [34.8, 35, 34.9, 35.3, 35, 35.3, 35.1, 35.3, 35.3, 34.9,
        34.9, 35.3, 35, 35.1, 35.1, 35.1, 34.8, 35.1, 35.1, 35]

mu0 = 35  # Проектный размер
alpha = 0.05  # Уровень значимости

# Вычисление выборочного среднего и стандартного отклонения
n = ?
X_bar = ?
S = ?  # ddof=1 для исправленного стандартного отклонения

# Вычисление t-статистики
t_stat = ?
print(f"t-статистика: {t_stat}")

# Число степеней свободы
df = n - 1

# Критическое значение для двусторонней гипотезы
t_crit = ?
print(f"Критическое значение t: {t_crit}")

# Вычисление p-value
p_value = ?
print(f"p-value: {p_value}")

# Выводы о гипотезах

# %% [markdown]
# ### Задание 6.
#
# Двумя приборами измерены размеры 5 деталей. Результаты измерений приведены в массивах X, Y. Пусть $Mx$ – средний размер деталей в генеральной совокупности согласно измерениям первого прибора, $My$ – то же самое для 2-го прибора. Выдвигается гипотеза $H0: Mx = My$ при альтернативной $H1: Mx ≠ My$. Проверить $H0$ при $α = 0.05$.
#
# Используя критерий Стьюдента рассчитать критическое значение и p-value.
#
# $d_i = X_i - Y_i,$
#
# $t = \frac{\bar{d}}{S_d / \sqrt{n}}.$
#
# На основе полученных значений сделать вывод о принятии нулевой гипотезы (добавить текстовый вывод).

# %%
import numpy as np
from scipy.stats import t

# Данные (пример)
X = np.array([6, 7, 8, 5, 7.5])  # Измерения первого прибора
Y = np.array([7, 6, 8, 7, 8])    # Измерения второго прибора
alpha = 0.05  # Уровень значимости

# Вычисление разностей
d = ?

# Вычисление среднего значения разностей и стандартного отклонения
n = len(d)
d_bar = ?
S_d = ?  # ddof=1 для исправленного стандартного отклонения

# Вычисление t-статистики
t_stat = d_bar / (S_d / np.sqrt(n))
print(f"t-статистика: {t_stat}")

# Число степеней свободы
df = n - 1

# Критическое значение для двусторонней гипотезы
t_crit = ?
print(f"Критическое значение t: {t_crit}")

# Вычисление p-value
p_value = ?
print(f"p-value: {p_value}")
